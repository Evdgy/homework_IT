# %%
#Find all lines containing the word "quick" in file1.txt and save to quick.txt
# !grep -w is file1.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 #Find all lines containing the word "quick" in file1.txt and save to quick.txt
# ----> 2 grep -w is file1.txt
#
# NameError: name 'grep' is not defined

# %%
# !pwd
# Out:
# /c/Projects/homework_IT
